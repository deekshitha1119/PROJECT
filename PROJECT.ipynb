# %%
SOCIAL MEDIA USAGE AND EMOTIONAL WELLBEING

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
#to read csv file we use .read_csv()
data='val.csv'
df=pd.read_csv(data)
print(df)
# Out:
#      User_ID   Age  Gender   Platform  Daily_Usage_Time (minutes)  \
# 0        NaN   NaN     NaN        NaN                         NaN
# 1       10.0  31.0    Male  Instagram                       170.0
# 2        NaN   NaN     NaN        NaN                         NaN
# 3      877.0  32.0  Female  Instagram                       155.0
# 4        NaN   NaN     NaN        NaN                         NaN
# ..       ...   ...     ...        ...                         ...
# 291    109.0  29.0  Female   LinkedIn                        55.0
# 292      NaN   NaN     NaN        NaN                         NaN
# 293     99.0  21.0  Female   Facebook                        75.0
# 294      NaN   NaN     NaN        NaN                         NaN
# 295    493.0  24.0  Female  Instagram                       200.0
#
#      Posts_Per_Day  Likes_Received_Per_Day  Comments_Received_Per_Day  \
# 0              NaN                     NaN                        NaN
# 1              5.0                    80.0                       20.0
# 2              NaN                     NaN                        NaN
# 3              6.0                    75.0                       25.0
# 4              NaN                     NaN                        NaN
# ..             ...                     ...                        ...
# 291            2.0                    15.0                        5.0
# 292            NaN                     NaN                        NaN
# 293            2.0                    25.0                       13.0
# 294            NaN                     NaN                        NaN
# 295            6.0                   100.0                       18.0
#
#      Messages_Sent_Per_Day Dominant_Emotion
# 0                      NaN              NaN
# 1                     35.0        Happiness
# 2                      NaN              NaN
# 3                     38.0        Happiness
# 4                      NaN              NaN
# ..                     ...              ...
# 291                   10.0          Neutral
# 292                    NaN              NaN
# 293                   19.0          Anxiety
# 294                    NaN              NaN
# 295                   39.0          Neutral
#
# [296 rows x 10 columns]

# %%
#to get the number of columns in table
df.columns
# Out:
# Index(['User_ID', 'Age', 'Gender', 'Platform', 'Daily_Usage_Time (minutes)',
#        'Posts_Per_Day', 'Likes_Received_Per_Day', 'Comments_Received_Per_Day',
#        'Messages_Sent_Per_Day', 'Dominant_Emotion'],
#       dtype='object')

# %%
#to get first 5 rows of data(as default)
df.head()
# Out:
#    User_ID   Age  Gender   Platform  Daily_Usage_Time (minutes)  \
# 0      NaN   NaN     NaN        NaN                         NaN
# 1     10.0  31.0    Male  Instagram                       170.0
# 2      NaN   NaN     NaN        NaN                         NaN
# 3    877.0  32.0  Female  Instagram                       155.0
# 4      NaN   NaN     NaN        NaN                         NaN
#
#    Posts_Per_Day  Likes_Received_Per_Day  Comments_Received_Per_Day  \
# 0            NaN                     NaN                        NaN
# 1            5.0                    80.0                       20.0
# 2            NaN                     NaN                        NaN
# 3            6.0                    75.0                       25.0
# 4            NaN                     NaN                        NaN
#
#    Messages_Sent_Per_Day Dominant_Emotion
# 0                    NaN              NaN
# 1                   35.0        Happiness
# 2                    NaN              NaN
# 3                   38.0        Happiness
# 4                    NaN              NaN

# %%
#to get last 5 rows of data(as default)
df.tail()
# Out:
#      User_ID   Age  Gender   Platform  Daily_Usage_Time (minutes)  \
# 291    109.0  29.0  Female   LinkedIn                        55.0
# 292      NaN   NaN     NaN        NaN                         NaN
# 293     99.0  21.0  Female   Facebook                        75.0
# 294      NaN   NaN     NaN        NaN                         NaN
# 295    493.0  24.0  Female  Instagram                       200.0
#
#      Posts_Per_Day  Likes_Received_Per_Day  Comments_Received_Per_Day  \
# 291            2.0                    15.0                        5.0
# 292            NaN                     NaN                        NaN
# 293            2.0                    25.0                       13.0
# 294            NaN                     NaN                        NaN
# 295            6.0                   100.0                       18.0
#
#      Messages_Sent_Per_Day Dominant_Emotion
# 291                   10.0          Neutral
# 292                    NaN              NaN
# 293                   19.0          Anxiety
# 294                    NaN              NaN
# 295                   39.0          Neutral

# %%
#to get total summary of data statistics
df.describe()
# Out:
#           User_ID         Age  Daily_Usage_Time (minutes)  Posts_Per_Day  \
# count  148.000000  148.000000                  148.000000     148.000000
# mean   486.114865   27.250000                   94.695946       3.601351
# std    281.585538    3.889415                   42.922594       2.143618
# min      5.000000   21.000000                    1.000000       1.000000
# 25%    238.250000   24.000000                   60.000000       2.000000
# 50%    469.000000   27.000000                   85.000000       3.000000
# 75%    736.000000   30.000000                  120.000000       5.000000
# max    986.000000   35.000000                  200.000000      10.000000
#
#        Likes_Received_Per_Day  Comments_Received_Per_Day  \
# count              148.000000                 148.000000
# mean                38.777027                  15.527027
# std                 26.514743                  10.138125
# min                  2.000000                   2.000000
# 25%                 20.000000                   8.000000
# 50%                 33.000000                  14.000000
# 75%                 50.000000                  20.000000
# max                110.000000                  87.000000
#
#        Messages_Sent_Per_Day
# count             148.000000
# mean               22.918919
# std                 9.271061
# min                10.000000
# 25%                15.000000
# 50%                22.000000
# 75%                28.000000
# max                54.000000

# %%
#information of data
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 296 entries, 0 to 295
# Data columns (total 10 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   User_ID                     148 non-null    float64
#  1   Age                         148 non-null    float64
#  2   Gender                      148 non-null    object
#  3   Platform                    148 non-null    object
#  4   Daily_Usage_Time (minutes)  148 non-null    float64
#  5   Posts_Per_Day               148 non-null    float64
#  6   Likes_Received_Per_Day      148 non-null    float64
#  7   Comments_Received_Per_Day   148 non-null    float64
#  8   Messages_Sent_Per_Day       148 non-null    float64
#  9   Dominant_Emotion            148 non-null    object
# dtypes: float64(7), object(3)
# memory usage: 19.7+ KB

# %%
#to check the null values
df.isnull().sum()
# Out:
# User_ID                       148
# Age                           148
# Gender                        148
# Platform                      148
# Daily_Usage_Time (minutes)    148
# Posts_Per_Day                 148
# Likes_Received_Per_Day        148
# Comments_Received_Per_Day     148
# Messages_Sent_Per_Day         148
# Dominant_Emotion              148
# dtype: int64

# %%
#to remove null
df.dropna()
# Out:
#      User_ID   Age      Gender   Platform  Daily_Usage_Time (minutes)  \
# 1       10.0  31.0        Male  Instagram                       170.0
# 3      877.0  32.0      Female  Instagram                       155.0
# 5      230.0  26.0  Non-binary   Facebook                        45.0
# 7      876.0  28.0  Non-binary   Snapchat                       115.0
# 9      376.0  28.0  Non-binary   Snapchat                       115.0
# ..       ...   ...         ...        ...                         ...
# 287    277.0  27.0  Non-binary   LinkedIn                        55.0
# 289    830.0  26.0  Non-binary   Facebook                        45.0
# 291    109.0  29.0      Female   LinkedIn                        55.0
# 293     99.0  21.0      Female   Facebook                        75.0
# 295    493.0  24.0      Female  Instagram                       200.0
#
#      Posts_Per_Day  Likes_Received_Per_Day  Comments_Received_Per_Day  \
# 1              5.0                    80.0                       20.0
# 3              6.0                    75.0                       25.0
# 5              1.0                     8.0                        4.0
# 7              3.0                    38.0                       18.0
# 9              3.0                    38.0                       18.0
# ..             ...                     ...                        ...
# 287            1.0                     9.0                        2.0
# 289            1.0                     8.0                        4.0
# 291            2.0                    15.0                        5.0
# 293            2.0                    25.0                       13.0
# 295            6.0                   100.0                       18.0
#
#      Messages_Sent_Per_Day Dominant_Emotion
# 1                     35.0        Happiness
# 3                     38.0        Happiness
# 5                     12.0          Sadness
# 7                     27.0          Anxiety
# 9                     27.0          Anxiety
# ..                     ...              ...
# 287                   11.0          Anxiety
# 289                   12.0          Sadness
# 291                   10.0          Neutral
# 293                   19.0          Anxiety
# 295                   39.0          Neutral
#
# [148 rows x 10 columns]

# %%
#to check duplicate
df.duplicated().sum()
# Out:
# 154

# %%
#to remove duplicates
df.drop_duplicates()
# Out:
#      User_ID   Age      Gender   Platform  Daily_Usage_Time (minutes)  \
# 0        NaN   NaN         NaN        NaN                         NaN
# 1       10.0  31.0        Male  Instagram                       170.0
# 3      877.0  32.0      Female  Instagram                       155.0
# 5      230.0  26.0  Non-binary   Facebook                        45.0
# 7      876.0  28.0  Non-binary   Snapchat                       115.0
# ..       ...   ...         ...        ...                         ...
# 287    277.0  27.0  Non-binary   LinkedIn                        55.0
# 289    830.0  26.0  Non-binary   Facebook                        45.0
# 291    109.0  29.0      Female   LinkedIn                        55.0
# 293     99.0  21.0      Female   Facebook                        75.0
# 295    493.0  24.0      Female  Instagram                       200.0
#
#      Posts_Per_Day  Likes_Received_Per_Day  Comments_Received_Per_Day  \
# 0              NaN                     NaN                        NaN
# 1              5.0                    80.0                       20.0
# 3              6.0                    75.0                       25.0
# 5              1.0                     8.0                        4.0
# 7              3.0                    38.0                       18.0
# ..             ...                     ...                        ...
# 287            1.0                     9.0                        2.0
# 289            1.0                     8.0                        4.0
# 291            2.0                    15.0                        5.0
# 293            2.0                    25.0                       13.0
# 295            6.0                   100.0                       18.0
#
#      Messages_Sent_Per_Day Dominant_Emotion
# 0                      NaN              NaN
# 1                     35.0        Happiness
# 3                     38.0        Happiness
# 5                     12.0          Sadness
# 7                     27.0          Anxiety
# ..                     ...              ...
# 287                   11.0          Anxiety
# 289                   12.0          Sadness
# 291                   10.0          Neutral
# 293                   19.0          Anxiety
# 295                   39.0          Neutral
#
# [142 rows x 10 columns]

# %%
#to know how many column are present after duplicates remove
val=df.drop_duplicates(inplace=True)
print(val)
# Out:
# None

# %%
#to see the duplicate values sum
df.duplicated().sum()
# Out:
# 0

# %%
print(df)
# Out:
#      User_ID   Age      Gender   Platform  Daily_Usage_Time (minutes)  \
# 0        NaN   NaN         NaN        NaN                         NaN
# 1       10.0  31.0        Male  Instagram                       170.0
# 3      877.0  32.0      Female  Instagram                       155.0
# 5      230.0  26.0  Non-binary   Facebook                        45.0
# 7      876.0  28.0  Non-binary   Snapchat                       115.0
# ..       ...   ...         ...        ...                         ...
# 287    277.0  27.0  Non-binary   LinkedIn                        55.0
# 289    830.0  26.0  Non-binary   Facebook                        45.0
# 291    109.0  29.0      Female   LinkedIn                        55.0
# 293     99.0  21.0      Female   Facebook                        75.0
# 295    493.0  24.0      Female  Instagram                       200.0
#
#      Posts_Per_Day  Likes_Received_Per_Day  Comments_Received_Per_Day  \
# 0              NaN                     NaN                        NaN
# 1              5.0                    80.0                       20.0
# 3              6.0                    75.0                       25.0
# 5              1.0                     8.0                        4.0
# 7              3.0                    38.0                       18.0
# ..             ...                     ...                        ...
# 287            1.0                     9.0                        2.0
# 289            1.0                     8.0                        4.0
# 291            2.0                    15.0                        5.0
# 293            2.0                    25.0                       13.0
# 295            6.0                   100.0                       18.0
#
#      Messages_Sent_Per_Day Dominant_Emotion
# 0                      NaN              NaN
# 1                     35.0        Happiness
# 3                     38.0        Happiness
# 5                     12.0          Sadness
# 7                     27.0          Anxiety
# ..                     ...              ...
# 287                   11.0          Anxiety
# 289                   12.0          Sadness
# 291                   10.0          Neutral
# 293                   19.0          Anxiety
# 295                   39.0          Neutral
#
# [142 rows x 10 columns]

# %%
#to calculate avg age of users 
data='val.csv'
df=pd.read_csv(data)
df['Age']=pd.to_numeric(df['Age'],errors='coerce')
Mean=df['Age'].mean()
print(Mean)
# Out:
# 27.25

# %%
#average time spend on social media

# Load the CSV file
data = pd.read_csv('val.csv')

# Ensure 'Daily_Usage_Time (minutes)' column is numeric,
data['Daily_Usage_Time (minutes)'] = pd.to_numeric(data['Daily_Usage_Time (minutes)'], errors='coerce')

# Drop rows with NaN values in 'Daily_Usage_Time (minutes)' column
data = data.dropna(subset=['Daily_Usage_Time (minutes)'])

# Calculate the mean daily usage time by platform  #groupby function ,It allows you to
#split and group data, apply a function, and combine the results.
platform_usage_time = data.groupby('Platform')['Daily_Usage_Time (minutes)'].mean()

# Display the result
print(platform_usage_time)
# Out:
# Platform
# Facebook      67.314286
# Instagram    144.131579
# LinkedIn      62.105263
# Snapchat      95.789474
# Telegram      75.000000
# Twitter       87.480000
# Whatsapp      94.000000
# Name: Daily_Usage_Time (minutes), dtype: float64

# %%
#Visualization

# Plotting
plt.figure(figsize=(7,5))
platform_usage_time.plot(kind='bar', color='pink')
plt.xlabel('Platform')
plt.ylabel('Mean Daily Usage Time (minutes)')
plt.title('Mean Daily Usage Time by Platform')
plt.xticks(rotation=45)  #used to get/set the current tick location and labels
plt.tight_layout()
plt.show()

# %%
The bar plot shows that Instagram has the highest mean daily usage time at about 144 minutes, followed by Snapchat (96 minutes).
Whatsapp, Twitter, and Telegram also see notable usage (around 94, 87, and 75 minutes, respectively).
Facebook and LinkedIn have the lowest usage times, at about 67 and 62 minutes each.

# %%
#what are the typical emotion responses to social media interaction?

# Count the occurrences of each dominant emotion
emotion_counts = data['Dominant_Emotion'].value_counts()

# Display the emotion counts
print("Distribution of Dominant Emotions:")
print(emotion_counts)
# Out:
# Distribution of Dominant Emotions:
# Anxiety      32
# Neutral      30
# Happiness    28
# Sadness      25
# Boredom      18
# Anger        14
# Agression     1
# Name: Dominant_Emotion, dtype: int64

# %%
# Plotting
plt.figure(figsize=(8, 5))
emotion_counts.plot(kind='bar', color='lightpink')
plt.xlabel('Dominant Emotion')
plt.ylabel('Number of Occurrences')
plt.title('Distribution of Dominant Emotions in Social Media Interactions')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
The bar plot shows the distribution of dominant emotions in social media interactions. 
Anxiety is the most common emotion, with 32 occurrences, followed by Neutral (30), and Happiness (28). 
Sadness is also relatively frequent with 25 occurrences. Boredom (18), Anger (14), and Aggression (1) are less common.

# %%
#How does social media usage vary across different platform?


# List of columns to be converted to numeric
numeric_columns = ['Daily_Usage_Time (minutes)', 'Posts_Per_Day', 'Likes_Received_Per_Day', 'Comments_Received_Per_Day', 'Messages_Sent_Per_Day']

# Convert the relevant columns to numeric, coercing errors to NaN
data[numeric_columns] = data[numeric_columns].apply(pd.to_numeric, errors='coerce')

# Drop rows with NaN values in any of the numeric columns
data = data.dropna(subset=numeric_columns)

# Group by Platform and calculate the mean of usage metrics
platform_usage = data.groupby('Platform')[numeric_columns].mean()

# Display the average social media usage across platforms
print("Average Social Media Usage Across Platforms:")
print(platform_usage)
# Out:
# Average Social Media Usage Across Platforms:
#            Daily_Usage_Time (minutes)  Posts_Per_Day  Likes_Received_Per_Day  \
# Platform
# Facebook                    67.314286       2.514286               21.228571
# Instagram                  144.131579       5.921053               70.736842
# LinkedIn                    62.105263       1.842105               14.736842
# Snapchat                    95.789474       3.105263               33.894737
# Telegram                    75.000000       2.571429               29.285714
# Twitter                     87.480000       3.600000               36.760000
# Whatsapp                    94.000000       3.600000               52.000000
#
#            Comments_Received_Per_Day  Messages_Sent_Per_Day
# Platform
# Facebook                   10.000000              18.800000
# Instagram                  24.973684              32.315789
# LinkedIn                    5.736842              14.368421
# Snapchat                   14.789474              22.578947
# Telegram                   11.857143              20.285714
# Twitter                    17.360000              21.640000
# Whatsapp                   18.400000              24.200000

# %%
# Plotting
plt.figure(figsize=(10,5))

# Plotting all metrics in one figure
platform_usage.plot(kind='bar', ax=plt.gca(), color=['skyblue', 'lightgreen', 'lightcoral', 'lightskyblue', 'lightpink'])
plt.title('Average Social Media Usage Across Platforms')
plt.xlabel('Platform')
plt.ylabel('Average Value')
plt.xticks(rotation=45)
plt.legend(title='Metrics', loc='upper right')
plt.tight_layout()
plt.show()

# %%
The bar plot shows that Instagram users are the most active, with the highest averages in daily usage time (144 minutes), 
posts per day (5.9), likes received per day (71), comments received per day (25), and messages sent per day (32).
LinkedIn users are the least active across these metrics.

# %%
#is there a correlation between different social media usage patterns and emotional well-being?


# Select only the numeric columns
numeric_data = data.select_dtypes(include='number')

# Compute the correlation matrix
correlation_matrix = numeric_data.corr()

# Display the correlation matrix
print("Correlation Matrix:")
print(correlation_matrix)
# Out:
# Correlation Matrix:
#                              User_ID       Age  Daily_Usage_Time (minutes)  \
# User_ID                     1.000000  0.061255                    0.040505
# Age                         0.061255  1.000000                    0.112598
# Daily_Usage_Time (minutes)  0.040505  0.112598                    1.000000
# Posts_Per_Day               0.053350  0.060175                    0.680723
# Likes_Received_Per_Day      0.070061  0.105362                    0.883908
# Comments_Received_Per_Day   0.068372  0.120851                    0.569783
# Messages_Sent_Per_Day       0.062957  0.090366                    0.676196
#
#                             Posts_Per_Day  Likes_Received_Per_Day  \
# User_ID                          0.053350                0.070061
# Age                              0.060175                0.105362
# Daily_Usage_Time (minutes)       0.680723                0.883908
# Posts_Per_Day                    1.000000                0.733066
# Likes_Received_Per_Day           0.733066                1.000000
# Comments_Received_Per_Day        0.668336                0.651154
# Messages_Sent_Per_Day            0.737729                0.775534
#
#                             Comments_Received_Per_Day  Messages_Sent_Per_Day
# User_ID                                      0.068372               0.062957
# Age                                          0.120851               0.090366
# Daily_Usage_Time (minutes)                   0.569783               0.676196
# Posts_Per_Day                                0.668336               0.737729
# Likes_Received_Per_Day                       0.651154               0.775534
# Comments_Received_Per_Day                    1.000000               0.680794
# Messages_Sent_Per_Day                        0.680794               1.000000

# %%
# Plotting the correlation matrix as a heatmap
plt.figure(figsize=(10, 8))
plt.imshow(correlation_matrix, cmap='YlGnBu', interpolation='nearest')
plt.title('Correlation Matrix: Social Media Usage Patterns and Emotional Well-being')
plt.colorbar()

# Adding labels to axes
tick_labels = list(numeric_data.columns)
plt.xticks(range(len(tick_labels)), tick_labels, rotation=45)
plt.yticks(range(len(tick_labels)), tick_labels)

plt.tight_layout()
plt.show()

# %%
#how can we quantify the emotional well-being risk associated with different social media usage patterns?

# Define which emotions are considered negative
negative_emotions = ['Sadness', 'Anger', 'Fear']

# Create a new column to quantify emotional risk
data['Emotional_Risk'] = data['Dominant_Emotion'].apply(lambda x: 1 if x in negative_emotions else 0)

# Analyze the risk associated with different usage patterns
risk_by_platform = data.groupby('Platform')['Emotional_Risk'].mean()

# Display the emotional risk by platform
print("Emotional Risk by Platform:")
print(risk_by_platform)
# Out:
# Emotional Risk by Platform:
# Platform
# Facebook     0.228571
# Instagram    0.131579
# LinkedIn     0.157895
# Snapchat     0.263158
# Telegram     0.428571
# Twitter      0.520000
# Whatsapp     0.400000
# Name: Emotional_Risk, dtype: float64

# %%
plt.figure(figsize=(8, 6))
risk_by_platform.plot(kind='bar', color='lightpink')
plt.title('Emotional Risk by Platform')
plt.xlabel('Platform')
plt.ylabel('Mean Emotional Risk')
plt.xticks(rotation=45)
plt.ylim(0, 1)  # Setting y-axis limit from 0 to 1
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.tight_layout()
plt.show()

# %%
The bar plot shows that Twitter has the highest emotional risk (0.52), followed by Telegram (0.43) andWhatsapp (0.40).
Snapchat (0.26), Facebook (0.23), and LinkedIn (0.16) have lower risks,with Instagram having the lowest emotional risk (0.13).
